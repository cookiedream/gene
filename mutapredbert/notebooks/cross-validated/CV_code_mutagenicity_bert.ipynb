# %%
# !pip install torch torchvision --quiet
# !pip install transformers  --quiet
# !pip install pandas  --quiet
# !pip install numpy  --quiet
# !pip install sentencepiece  --quiet
# !pip install sentence-splitter  --quiet
# !pip install shap --quiet
# !pip install optuna --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 31.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 427.5 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.3/225.3 kB 22.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.7 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Imports**

# %%
import random
import torch
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AdamW,AutoModelForQuestionAnswering, get_linear_schedule_with_warmup, get_cosine_schedule_with_warmup
from transformers import DebertaTokenizer, DebertaModel, BartTokenizer
import math

# %% [markdown]
# # **Model loading**

# %%
# Use a GPU if you have one available (Runtime -> Change runtime type -> GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set seeds for reproducibility
random.seed(26)
np.random.seed(26)
torch.manual_seed(26)

tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased", do_lower_case=True)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
def get_optimizer_grouped_parameters(
    model, model_type,
    learning_rate, weight_decay,
    layerwise_learning_rate_decay
):
    no_decay = ["bias", "LayerNorm.weight"]
    # initialize lr for task specific layer
    optimizer_grouped_parameters = [
        {
            "params": [p for n, p in model.named_parameters() if "classifier" in n or "pooler" in n],
            "weight_decay": 0.0,
            "lr": learning_rate,
        },
    ]
    # initialize lrs for every layer
    num_layers = model.config.num_hidden_layers
    layers = [getattr(model, model_type).embeddings] + list(getattr(model, model_type).encoder.layer)
    layers.reverse()
    lr = learning_rate
    for layer in layers:
        lr *= layerwise_learning_rate_decay
        optimizer_grouped_parameters += [
            {
                "params": [p for n, p in layer.named_parameters() if not any(nd in n for nd in no_decay)],
                "weight_decay": weight_decay,
                "lr": lr,
            },
            {
                "params": [p for n, p in layer.named_parameters() if any(nd in n for nd in no_decay)],
                "weight_decay": 0.0,
                "lr": lr,
            },
        ]
    return optimizer_grouped_parameters

# %%
def encode_data(tokenizer, passages,questions, max_length):
    """Encode the question/passage pairs into features than can be fed to the model."""
    input_ids = []
    attention_masks = []

    for passage,question in zip(passages,questions):
        encoded_data = tokenizer.encode_plus(passage,question, max_length=max_length, pad_to_max_length=True, truncation='longest_first')
        encoded_pair = encoded_data["input_ids"]
        attention_mask = encoded_data["attention_mask"]

        input_ids.append(encoded_pair)
        attention_masks.append(attention_mask)

    return np.array(input_ids), np.array(attention_masks)

# %%
def predict(passage,question):
  sequence = tokenizer.encode_plus(passage,question, return_tensors="pt")['input_ids'].to(device)

  logits = model(sequence)[0]
  probabilities = torch.softmax(logits, dim=1).detach().cpu().tolist()[0]
  proba_yes = round(probabilities[1], 2)
  proba_no = round(probabilities[0], 2)

  #print(f"Question: {question}, Yes: {proba_yes}, No: {proba_no}")

  if (proba_yes >= proba_no):
    return True
  else:
    return False

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split



# Train and evaluate the accuracy of neural network with the addition of pruning mechanism
def train_and_evaluate(model,train_data_df,dev_data_df):
    passages_train = train_data_df.Abstract.values
    questions_train = train_data_df.questions.values
    answers_train = train_data_df.AMES.values.astype(int)

    passages_dev = dev_data_df.Abstract.values
    questions_dev = dev_data_df.questions.values
    answers_dev = dev_data_df.AMES.values.astype(int)

    # Encoding data
    max_seq_length = 512
    input_ids_train, attention_masks_train = encode_data(tokenizer, passages_train,questions_train, max_seq_length)
    input_ids_dev, attention_masks_dev = encode_data(tokenizer, passages_dev,questions_dev, max_seq_length)

    train_features = (input_ids_train, attention_masks_train, answers_train)
    dev_features = (input_ids_dev, attention_masks_dev, answers_dev)

    batch_size = 2
    train_features_tensors = [torch.tensor(feature, dtype=torch.long) for feature in train_features]
    dev_features_tensors = [torch.tensor(feature, dtype=torch.long) for feature in dev_features]

    train_dataset = TensorDataset(*train_features_tensors)
    dev_dataset = TensorDataset(*dev_features_tensors)

    train_sampler = RandomSampler(train_dataset)
    dev_sampler = SequentialSampler(dev_dataset)

    train_dataloader = DataLoader(train_dataset, sampler=train_sampler, batch_size=batch_size)
    dev_dataloader = DataLoader(dev_dataset, sampler=dev_sampler, batch_size=batch_size)

    learning_rate = 5e-5
    layerwise_learning_rate_decay = 0.9
    adam_epsilon = 1e-6
    use_bertadam = False

    # scheduler params
    num_epochs = 7
    num_warmup_steps = 0

    optimizer = AdamW(model.parameters(),
        lr=learning_rate,
        eps=adam_epsilon,
        correct_bias=not use_bertadam
    )
    scheduler = get_cosine_schedule_with_warmup(
        optimizer,
        num_warmup_steps=num_warmup_steps,
        num_training_steps=num_epochs
    )

    print("Done setting up optimizer\n")
    train_loss_values = []
    dev_acc_values = []
    state=[]

    for i in tqdm(range(num_epochs), desc="Epoch"):

      # Training
      print("In epoch ", i, "\n")
      epoch_train_loss = 0 # Cumulative loss
      model.train()
      #model.zero_grad()

      for step, batch in enumerate(train_dataloader):

          input_ids = batch[0].to(device)
          attention_masks = batch[1].to(device)
          labels = batch[2].to(device)
          model.zero_grad()
          outputs = model(input_ids, token_type_ids=None, attention_mask=attention_masks, labels=labels)

          loss = outputs[0]
          #loss = loss / grad_acc_steps
          epoch_train_loss += loss.item()

          loss.backward()
          torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
          optimizer.step()
          scheduler.step()

      epoch_train_loss = epoch_train_loss / len(train_dataloader)
      train_loss_values.append(epoch_train_loss)
      print("Epoch loss is", epoch_train_loss)

      # Evaluation
      epoch_dev_accuracy = 0 # Cumulative accuracy
      model.eval()

      for batch in dev_dataloader:

        input_ids = batch[0].to(device)
        attention_masks = batch[1].to(device)
        labels = batch[2]

        with torch.no_grad():
            outputs = model(input_ids, token_type_ids=None, attention_mask=attention_masks)

        logits = outputs[0]
        logits = logits.detach().cpu().numpy()

        predictions = np.argmax(logits, axis=1).flatten()
        labels = labels.numpy().flatten()

        epoch_dev_accuracy += np.sum(predictions == labels) / len(labels)

      epoch_dev_accuracy = epoch_dev_accuracy / len(dev_dataloader)
      print("Epoch accuracy is",epoch_dev_accuracy )
      dev_acc_values.append(epoch_dev_accuracy)
      temp=model
      state.append(temp)

    index = dev_acc_values.index(max(dev_acc_values))
    best = state[index]
    return best

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split



# Train and evaluate the accuracy of neural network with the addition of pruning mechanism
def train_and_evaluate(model,train_data_df,dev_data_df):
    passages_train = train_data_df.Abstract.values
    questions_train = train_data_df.questions.values
    answers_train = train_data_df.AMES.values.astype(int)

    passages_dev = dev_data_df.Abstract.values
    questions_dev = dev_data_df.questions.values
    answers_dev = dev_data_df.AMES.values.astype(int)

    # Encoding data
    max_seq_length = 512
    input_ids_train, attention_masks_train = encode_data(tokenizer, passages_train,questions_train, max_seq_length)
    input_ids_dev, attention_masks_dev = encode_data(tokenizer, passages_dev,questions_dev, max_seq_length)

    train_features = (input_ids_train, attention_masks_train, answers_train)
    dev_features = (input_ids_dev, attention_masks_dev, answers_dev)

    batch_size = 2
    train_features_tensors = [torch.tensor(feature, dtype=torch.long) for feature in train_features]
    dev_features_tensors = [torch.tensor(feature, dtype=torch.long) for feature in dev_features]

    train_dataset = TensorDataset(*train_features_tensors)
    dev_dataset = TensorDataset(*dev_features_tensors)

    train_sampler = RandomSampler(train_dataset)
    dev_sampler = SequentialSampler(dev_dataset)

    train_dataloader = DataLoader(train_dataset, sampler=train_sampler, batch_size=batch_size)
    dev_dataloader = DataLoader(dev_dataset, sampler=dev_sampler, batch_size=batch_size)

    learning_rate = 5e-5
    layerwise_learning_rate_decay = 0.9
    weight_decay = 0.01
    adam_epsilon = 1e-6
    use_bertadam = False
    # scheduler params
    num_epochs = 7
    num_warmup_steps = 0
    _model_type = 'bert'

    grouped_optimizer_params = get_optimizer_grouped_parameters(
        model, _model_type,
        learning_rate, weight_decay,
        layerwise_learning_rate_decay
    )
    optimizer = AdamW(
        grouped_optimizer_params,
        lr=learning_rate,
        eps=adam_epsilon,
        correct_bias=not use_bertadam
    )
    scheduler = get_cosine_schedule_with_warmup(
        optimizer,
        num_warmup_steps=num_warmup_steps,
        num_training_steps=num_epochs
    )

    (learning_rates1, learning_rates2, learning_rates3, learning_rates4,
    learning_rates5, learning_rates6, learning_rates7, learning_rates8,
    learning_rates9, learning_rates10, learning_rates11, learning_rates12,
    learning_rates13, learning_rates14) = [[] for i in range(14)]

    learning_rates1.append(optimizer.param_groups[0]["lr"])
    learning_rates2.append(optimizer.param_groups[2]["lr"])
    learning_rates3.append(optimizer.param_groups[4]["lr"])
    learning_rates4.append(optimizer.param_groups[6]["lr"])
    learning_rates5.append(optimizer.param_groups[8]["lr"])
    learning_rates6.append(optimizer.param_groups[10]["lr"])
    learning_rates7.append(optimizer.param_groups[12]["lr"])
    learning_rates8.append(optimizer.param_groups[14]["lr"])
    learning_rates9.append(optimizer.param_groups[16]["lr"])
    learning_rates10.append(optimizer.param_groups[18]["lr"])
    learning_rates11.append(optimizer.param_groups[20]["lr"])
    learning_rates12.append(optimizer.param_groups[22]["lr"])
    learning_rates13.append(optimizer.param_groups[24]["lr"])
    learning_rates14.append(optimizer.param_groups[26]["lr"])

    for epoch in range(num_epochs):
        optimizer.step()
        scheduler.step()
        learning_rates1.append(optimizer.param_groups[0]["lr"])
        learning_rates2.append(optimizer.param_groups[2]["lr"])
        learning_rates3.append(optimizer.param_groups[4]["lr"])
        learning_rates4.append(optimizer.param_groups[6]["lr"])
        learning_rates5.append(optimizer.param_groups[8]["lr"])
        learning_rates6.append(optimizer.param_groups[10]["lr"])
        learning_rates7.append(optimizer.param_groups[12]["lr"])
        learning_rates8.append(optimizer.param_groups[14]["lr"])
        learning_rates9.append(optimizer.param_groups[16]["lr"])
        learning_rates10.append(optimizer.param_groups[18]["lr"])
        learning_rates11.append(optimizer.param_groups[20]["lr"])
        learning_rates12.append(optimizer.param_groups[22]["lr"])
        learning_rates13.append(optimizer.param_groups[24]["lr"])
        learning_rates14.append(optimizer.param_groups[26]["lr"])

    print("Done setting up optimizer\n")
    train_loss_values = []
    dev_acc_values = []
    state=[]

    #num_epochs=5
    for i in tqdm(range(num_epochs), desc="Epoch"):

      # Training
      print("In epoch ", i, "\n")
      epoch_train_loss = 0 # Cumulative loss
      model.train()
      #model.zero_grad()

      for step, batch in enumerate(train_dataloader):

          input_ids = batch[0].to(device)
          attention_masks = batch[1].to(device)
          labels = batch[2].to(device)
          model.zero_grad()
          outputs = model(input_ids, token_type_ids=None, attention_mask=attention_masks, labels=labels)

          loss = outputs[0]
          #loss = loss / grad_acc_steps
          epoch_train_loss += loss.item()

          loss.backward()
          torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
          optimizer.step()
          scheduler.step()

      epoch_train_loss = epoch_train_loss / len(train_dataloader)
      train_loss_values.append(epoch_train_loss)
      print("Epoch loss is", epoch_train_loss)

      # Evaluation
      epoch_dev_accuracy = 0 # Cumulative accuracy
      model.eval()

      for batch in dev_dataloader:

        input_ids = batch[0].to(device)
        attention_masks = batch[1].to(device)
        labels = batch[2]

        with torch.no_grad():
            outputs = model(input_ids, token_type_ids=None, attention_mask=attention_masks)

        logits = outputs[0]
        logits = logits.detach().cpu().numpy()

        predictions = np.argmax(logits, axis=1).flatten()
        labels = labels.numpy().flatten()

        epoch_dev_accuracy += np.sum(predictions == labels) / len(labels)

      epoch_dev_accuracy = epoch_dev_accuracy / len(dev_dataloader)
      print("Epoch accuracy is",epoch_dev_accuracy )
      dev_acc_values.append(epoch_dev_accuracy)
      temp=model
      state.append(temp)

    index = dev_acc_values.index(max(dev_acc_values))
    best = state[index]
    return best

# %%
import pandas as pd

df=pd.read_csv('./new_data_mutagenicity.csv')

# Apply the function to the column
df['label'] = df['label'].apply(lambda x: x.startswith("['True"))
new_column_names = {'text': 'Abstract', 'label': 'AMES'}
df.rename(columns=new_column_names, inplace=True)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import pandas as pd
import gc

kf = KFold(n_splits=5, random_state=42, shuffle=True)
CV_accuracy_array=[]
CV_macro_avg_array=[]
CV_weighted_avg_array=[]
for train_index, test_index in kf.split(df):
    print("TRAIN:", train_index)
    print("TEST:", test_index)
    train_data_df, dev_data_df = df.loc[train_index], df.loc[test_index]
    model = AutoModelForSequenceClassification.from_pretrained("bert-large-uncased")
    model.to(device)
    model=train_and_evaluate(model,train_data_df,dev_data_df)
    filter=list(dev_data_df.index)
    preds=[]
    index=[]
    for i in filter:
        try:
          passage=dev_data_df.Abstract[i]
          question =dev_data_df.questions[i]
          answer=predict(passage,question)
          preds.append(answer)
          index.append(i)
        except Exception as e:
          print(e)
          continue
    dev=dev_data_df[dev_data_df.index.isin(index)]
    true_results=dev['AMES'].tolist()
    print(classification_report(true_results, preds))
    results = classification_report(true_results, preds,output_dict=True,)
    CV_accuracy_array.append(results['accuracy'])
    CV_macro_avg_array.append(results['macro avg']['f1-score'])
    CV_weighted_avg_array.append(results['weighted avg']['f1-score'])
    del model
    gc.collect()
    torch.cuda.empty_cache()
# Out:
# TRAIN: [   0    1    2 ... 1643 1644 1645]
# TEST: [  15   23   29   30   32   43   44   49   51   56   59   63   65   67
#    69   70   73   76   78   99  100  101  107  109  115  123  124  128
#   135  141  148  162  163  168  170  173  175  184  185  192  198  199
#   203  212  220  226  231  237  239  240  244  247  251  259  261  266
#   270  271  274  275  289  297  298  300  303  306  309  316  324  331
#   332  339  342  344  350  351  352  353  366  367  371  374  383  394
#   398  405  408  411  413  414  415  416  420  422  425  426  433  438
#   450  451  464  471  479  481  482  483  486  490  493  494  497  526
#   527  529  534  538  543  551  552  554  560  561  567  575  582  584
#   585  588  589  590  591  597  610  613  614  617  619  620  621  629
#   651  654  668  669  674  679  680  682  694  706  707  720  724  727
#   730  741  744  752  754  764  765  767  772  780  792  798  802  803
#   809  810  813  816  818  838  842  844  845  847  855  861  865  867
#   873  874  879  887  888  889  893  899  901  905  906  907  915  916
#   917  925  926  939  942  964  966  982  987  988  993 1006 1007 1018
#  1027 1029 1030 1031 1036 1037 1043 1055 1058 1063 1074 1087 1089 1093
#  1096 1100 1101 1102 1112 1114 1116 1117 1120 1124 1128 1133 1138 1142
#  1145 1146 1155 1159 1160 1164 1165 1174 1178 1181 1189 1197 1208 1212
#  1214 1216 1230 1232 1234 1235 1237 1240 1242 1273 1274 1277 1278 1285
#  1286 1288 1301 1305 1314 1316 1324 1325 1335 1336 1343 1344 1345 1350
#  1356 1357 1359 1362 1365 1376 1385 1389 1391 1399 1401 1404 1407 1414
#  1417 1425 1436 1440 1442 1453 1463 1464 1487 1489 1497 1506 1511 1514
#  1524 1532 1535 1536 1537 1549 1552 1560 1567 1569 1572 1576 1579 1582
#  1587 1591 1604 1611 1614 1625 1634 1636]
# Downloading model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-large-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2393: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Done setting up optimizer
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch:   0%|          | 0/7 [00:00<?, ?it/s]
# In epoch  0
#
# Epoch loss is 0.7167495363660858
# Epoch accuracy is 0.6606060606060606
# In epoch  1
#
# Epoch loss is 0.7683839026476202
# Epoch accuracy is 0.6515151515151515
# In epoch  2
#
# Epoch loss is 0.7393827929365304
# Epoch accuracy is 0.6393939393939394
# In epoch  3
#
# Epoch loss is 0.7592198187287184
# Epoch accuracy is 0.5454545454545454
# In epoch  4
#
# Epoch loss is 0.7045888648025895
# Epoch accuracy is 0.45454545454545453
# In epoch  5
#
# Epoch loss is 0.6992388351347671
# Epoch accuracy is 0.5454545454545454
# In epoch  6
#
# Epoch loss is 0.7051279864593842
# Token indices sequence length is longer than the specified maximum sequence length for this model (580 > 512). Running this sequence through the model will result in indexing errors
# Epoch accuracy is 0.5454545454545454
# The expanded size of the tensor (580) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 580].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2209) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2209].  Tensor sizes: [1, 512]
# The expanded size of the tensor (644) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 644].  Tensor sizes: [1, 512]
# The expanded size of the tensor (923) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 923].  Tensor sizes: [1, 512]
# The expanded size of the tensor (547) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 547].  Tensor sizes: [1, 512]
# The expanded size of the tensor (695) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 695].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2275) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2275].  Tensor sizes: [1, 512]
# The expanded size of the tensor (528) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 528].  Tensor sizes: [1, 512]
# The expanded size of the tensor (523) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 523].  Tensor sizes: [1, 512]
# The expanded size of the tensor (777) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 777].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1563) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1563].  Tensor sizes: [1, 512]
# The expanded size of the tensor (759) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 759].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1244) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1244].  Tensor sizes: [1, 512]
# The expanded size of the tensor (613) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 613].  Tensor sizes: [1, 512]
# The expanded size of the tensor (536) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 536].  Tensor sizes: [1, 512]
# The expanded size of the tensor (558) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 558].  Tensor sizes: [1, 512]
# The expanded size of the tensor (910) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 910].  Tensor sizes: [1, 512]
# The expanded size of the tensor (570) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 570].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1029) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1029].  Tensor sizes: [1, 512]
# The expanded size of the tensor (577) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 577].  Tensor sizes: [1, 512]
# The expanded size of the tensor (617) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 617].  Tensor sizes: [1, 512]
# The expanded size of the tensor (601) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 601].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1716) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1716].  Tensor sizes: [1, 512]
# The expanded size of the tensor (542) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 542].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1660) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1660].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1660) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1660].  Tensor sizes: [1, 512]
# The expanded size of the tensor (520) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 520].  Tensor sizes: [1, 512]
# The expanded size of the tensor (594) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 594].  Tensor sizes: [1, 512]
# The expanded size of the tensor (546) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 546].  Tensor sizes: [1, 512]
# The expanded size of the tensor (538) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 538].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1716) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1716].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2353) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2353].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2297) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2297].  Tensor sizes: [1, 512]
# The expanded size of the tensor (742) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 742].  Tensor sizes: [1, 512]
# The expanded size of the tensor (541) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 541].  Tensor sizes: [1, 512]
# The expanded size of the tensor (585) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 585].  Tensor sizes: [1, 512]
# The expanded size of the tensor (3220) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 3220].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1248) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1248].  Tensor sizes: [1, 512]
# The expanded size of the tensor (698) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 698].  Tensor sizes: [1, 512]
# The expanded size of the tensor (588) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 588].  Tensor sizes: [1, 512]
# The expanded size of the tensor (609) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 609].  Tensor sizes: [1, 512]
# The expanded size of the tensor (593) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 593].  Tensor sizes: [1, 512]
# The expanded size of the tensor (581) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 581].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2294) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2294].  Tensor sizes: [1, 512]
# The expanded size of the tensor (559) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 559].  Tensor sizes: [1, 512]
# The expanded size of the tensor (771) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 771].  Tensor sizes: [1, 512]
# The expanded size of the tensor (513) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 513].  Tensor sizes: [1, 512]
# The expanded size of the tensor (564) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 564].  Tensor sizes: [1, 512]
# The expanded size of the tensor (787) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 787].  Tensor sizes: [1, 512]
# The expanded size of the tensor (608) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 608].  Tensor sizes: [1, 512]
# The expanded size of the tensor (872) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 872].  Tensor sizes: [1, 512]
# The expanded size of the tensor (623) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 623].  Tensor sizes: [1, 512]
# The expanded size of the tensor (707) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 707].  Tensor sizes: [1, 512]
# The expanded size of the tensor (520) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 520].  Tensor sizes: [1, 512]
# The expanded size of the tensor (532) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 532].  Tensor sizes: [1, 512]
# The expanded size of the tensor (540) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 540].  Tensor sizes: [1, 512]
# The expanded size of the tensor (679) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 679].  Tensor sizes: [1, 512]
# The expanded size of the tensor (575) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 575].  Tensor sizes: [1, 512]
# The expanded size of the tensor (560) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 560].  Tensor sizes: [1, 512]
# The expanded size of the tensor (513) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 513].  Tensor sizes: [1, 512]
# The expanded size of the tensor (556) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 556].  Tensor sizes: [1, 512]
# The expanded size of the tensor (634) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 634].  Tensor sizes: [1, 512]
# The expanded size of the tensor (596) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 596].  Tensor sizes: [1, 512]
# The expanded size of the tensor (530) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 530].  Tensor sizes: [1, 512]
# The expanded size of the tensor (548) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 548].  Tensor sizes: [1, 512]
# The expanded size of the tensor (742) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 742].  Tensor sizes: [1, 512]
# The expanded size of the tensor (577) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 577].  Tensor sizes: [1, 512]
# The expanded size of the tensor (556) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 556].  Tensor sizes: [1, 512]
# The expanded size of the tensor (609) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 609].  Tensor sizes: [1, 512]
# The expanded size of the tensor (577) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 577].  Tensor sizes: [1, 512]
# The expanded size of the tensor (625) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 625].  Tensor sizes: [1, 512]
# The expanded size of the tensor (520) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 520].  Tensor sizes: [1, 512]
# The expanded size of the tensor (559) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 559].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1287) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1287].  Tensor sizes: [1, 512]
# The expanded size of the tensor (542) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 542].  Tensor sizes: [1, 512]
# The expanded size of the tensor (539) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 539].  Tensor sizes: [1, 512]
# The expanded size of the tensor (541) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 541].  Tensor sizes: [1, 512]
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00       114
#         True       0.55      1.00      0.71       139
#
#     accuracy                           0.55       253
#    macro avg       0.27      0.50      0.35       253
# weighted avg       0.30      0.55      0.39       253
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# TRAIN: [   0    1    2 ... 1643 1644 1645]
# TEST: [  10   18   31   41   48   54   58   81   83   86   88   96  111  113
#   126  129  131  140  142  147  155  156  158  164  174  178  179  181
#   188  195  196  208  209  210  214  218  221  233  236  243  254  265
#   277  282  285  286  287  290  291  292  294  296  308  310  312  322
#   323  326  327  333  341  346  348  354  355  358  360  361  363  365
#   370  375  377  380  381  382  390  410  419  423  427  428  429  430
#   432  435  439  447  453  458  461  462  468  477  478  485  495  500
#   506  513  514  516  518  522  528  530  532  535  544  548  555  566
#   570  571  576  578  583  596  598  599  601  602  607  611  615  618
#   626  628  631  634  636  637  643  650  660  664  670  678  692  693
#   700  704  705  710  711  712  714  715  721  722  743  745  755  756
#   757  759  774  781  782  785  786  787  808  811  819  820  829  832
#   834  836  839  841  843  846  857  864  886  892  904  909  910  918
#   930  931  937  940  943  944  950  962  963  973  978  990  997  998
#  1000 1004 1010 1022 1026 1033 1049 1052 1054 1057 1068 1075 1078 1079
#  1085 1090 1094 1097 1103 1110 1113 1121 1132 1134 1157 1163 1169 1173
#  1176 1179 1185 1187 1190 1191 1193 1198 1203 1205 1210 1211 1223 1231
#  1239 1245 1249 1251 1255 1258 1260 1262 1269 1270 1280 1281 1289 1295
#  1302 1303 1304 1308 1310 1311 1319 1320 1330 1331 1333 1341 1347 1348
#  1351 1353 1355 1360 1366 1368 1374 1380 1381 1383 1384 1392 1415 1421
#  1431 1435 1445 1446 1449 1450 1456 1461 1467 1471 1475 1477 1488 1491
#  1493 1498 1507 1512 1517 1520 1527 1530 1531 1539 1547 1554 1555 1556
#  1557 1559 1561 1566 1575 1577 1586 1588 1592 1601 1606 1608 1609 1610
#  1612 1626 1628 1632 1639 1640 1641]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-large-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2393: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Done setting up optimizer
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch:   0%|          | 0/7 [00:00<?, ?it/s]
# In epoch  0
#
# Epoch loss is 0.7379098599018777
# Epoch accuracy is 0.7454545454545455
# In epoch  1
#
# Epoch loss is 0.8882794410240453
# Epoch accuracy is 0.7363636363636363
# In epoch  2
#
# Epoch loss is 0.7120708671749296
# Epoch accuracy is 0.7727272727272727
# In epoch  3
#
# Epoch loss is 0.6010632891587211
# Epoch accuracy is 0.7848484848484848
# In epoch  4
#
# Epoch loss is 0.4162007337002393
# Epoch accuracy is 0.806060606060606
# In epoch  5
#
# Epoch loss is 0.3582283707948262
# Epoch accuracy is 0.8121212121212121
# In epoch  6
#
# Epoch loss is 0.261374274855583
# Epoch accuracy is 0.803030303030303
# The expanded size of the tensor (574) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 574].  Tensor sizes: [1, 512]
# The expanded size of the tensor (520) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 520].  Tensor sizes: [1, 512]
# The expanded size of the tensor (605) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 605].  Tensor sizes: [1, 512]
# The expanded size of the tensor (540) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 540].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2852) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2852].  Tensor sizes: [1, 512]
# The expanded size of the tensor (609) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 609].  Tensor sizes: [1, 512]
# The expanded size of the tensor (609) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 609].  Tensor sizes: [1, 512]
# The expanded size of the tensor (514) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 514].  Tensor sizes: [1, 512]
# The expanded size of the tensor (564) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 564].  Tensor sizes: [1, 512]
# The expanded size of the tensor (521) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 521].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2294) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2294].  Tensor sizes: [1, 512]
# The expanded size of the tensor (527) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 527].  Tensor sizes: [1, 512]
# The expanded size of the tensor (594) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 594].  Tensor sizes: [1, 512]
# The expanded size of the tensor (3220) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 3220].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2353) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2353].  Tensor sizes: [1, 512]
# The expanded size of the tensor (604) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 604].  Tensor sizes: [1, 512]
# The expanded size of the tensor (3220) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 3220].  Tensor sizes: [1, 512]
# The expanded size of the tensor (712) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 712].  Tensor sizes: [1, 512]
# The expanded size of the tensor (911) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 911].  Tensor sizes: [1, 512]
# The expanded size of the tensor (738) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 738].  Tensor sizes: [1, 512]
# The expanded size of the tensor (790) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 790].  Tensor sizes: [1, 512]
# The expanded size of the tensor (604) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 604].  Tensor sizes: [1, 512]
# The expanded size of the tensor (655) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 655].  Tensor sizes: [1, 512]
# The expanded size of the tensor (569) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 569].  Tensor sizes: [1, 512]
# The expanded size of the tensor (534) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 534].  Tensor sizes: [1, 512]
# The expanded size of the tensor (634) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 634].  Tensor sizes: [1, 512]
# The expanded size of the tensor (603) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 603].  Tensor sizes: [1, 512]
# The expanded size of the tensor (569) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 569].  Tensor sizes: [1, 512]
# The expanded size of the tensor (632) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 632].  Tensor sizes: [1, 512]
# The expanded size of the tensor (632) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 632].  Tensor sizes: [1, 512]
# The expanded size of the tensor (603) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 603].  Tensor sizes: [1, 512]
# The expanded size of the tensor (609) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 609].  Tensor sizes: [1, 512]
# The expanded size of the tensor (534) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 534].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2275) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2275].  Tensor sizes: [1, 512]
# The expanded size of the tensor (591) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 591].  Tensor sizes: [1, 512]
# The expanded size of the tensor (607) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 607].  Tensor sizes: [1, 512]
# The expanded size of the tensor (529) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 529].  Tensor sizes: [1, 512]
# The expanded size of the tensor (911) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 911].  Tensor sizes: [1, 512]
# The expanded size of the tensor (514) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 514].  Tensor sizes: [1, 512]
# The expanded size of the tensor (916) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 916].  Tensor sizes: [1, 512]
# The expanded size of the tensor (3054) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 3054].  Tensor sizes: [1, 512]
# The expanded size of the tensor (623) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 623].  Tensor sizes: [1, 512]
# The expanded size of the tensor (526) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 526].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1796) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1796].  Tensor sizes: [1, 512]
# The expanded size of the tensor (544) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 544].  Tensor sizes: [1, 512]
# The expanded size of the tensor (773) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 773].  Tensor sizes: [1, 512]
# The expanded size of the tensor (609) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 609].  Tensor sizes: [1, 512]
# The expanded size of the tensor (766) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 766].  Tensor sizes: [1, 512]
# The expanded size of the tensor (923) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 923].  Tensor sizes: [1, 512]
# The expanded size of the tensor (522) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 522].  Tensor sizes: [1, 512]
# The expanded size of the tensor (582) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 582].  Tensor sizes: [1, 512]
# The expanded size of the tensor (767) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 767].  Tensor sizes: [1, 512]
# The expanded size of the tensor (599) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 599].  Tensor sizes: [1, 512]
# The expanded size of the tensor (609) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 609].  Tensor sizes: [1, 512]
# The expanded size of the tensor (526) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 526].  Tensor sizes: [1, 512]
# The expanded size of the tensor (660) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 660].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1244) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1244].  Tensor sizes: [1, 512]
# The expanded size of the tensor (921) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 921].  Tensor sizes: [1, 512]
# The expanded size of the tensor (540) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 540].  Tensor sizes: [1, 512]
# The expanded size of the tensor (564) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 564].  Tensor sizes: [1, 512]
# The expanded size of the tensor (559) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 559].  Tensor sizes: [1, 512]
# The expanded size of the tensor (536) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 536].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1293) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1293].  Tensor sizes: [1, 512]
# The expanded size of the tensor (612) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 612].  Tensor sizes: [1, 512]
# The expanded size of the tensor (558) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 558].  Tensor sizes: [1, 512]
# The expanded size of the tensor (770) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 770].  Tensor sizes: [1, 512]
# The expanded size of the tensor (555) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 555].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2852) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2852].  Tensor sizes: [1, 512]
# The expanded size of the tensor (985) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 985].  Tensor sizes: [1, 512]
# The expanded size of the tensor (524) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 524].  Tensor sizes: [1, 512]
# The expanded size of the tensor (921) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 921].  Tensor sizes: [1, 512]
# The expanded size of the tensor (556) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 556].  Tensor sizes: [1, 512]
# The expanded size of the tensor (534) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 534].  Tensor sizes: [1, 512]
# The expanded size of the tensor (539) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 539].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2297) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2297].  Tensor sizes: [1, 512]
# The expanded size of the tensor (527) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 527].  Tensor sizes: [1, 512]
#               precision    recall  f1-score   support
#
#        False       0.71      0.89      0.79       106
#         True       0.90      0.73      0.81       147
#
#     accuracy                           0.80       253
#    macro avg       0.80      0.81      0.80       253
# weighted avg       0.82      0.80      0.80       253
#
# TRAIN: [   1    4    7 ... 1642 1643 1645]
# TEST: [   0    2    3    5    6    9   12   24   25   27   33   39   42   45
#    47   52   55   60   62   66   68   71   72   74   77   80   82   84
#    85   92   94   97  102  104  105  106  110  117  118  120  125  132
#   136  137  138  139  145  165  167  171  182  183  193  194  204  211
#   213  215  222  223  224  227  228  232  235  238  242  248  249  250
#   256  258  260  267  272  273  280  281  299  302  305  307  311  314
#   318  319  321  325  328  329  334  336  349  359  362  364  368  373
#   376  388  393  404  409  421  424  434  436  440  442  445  446  448
#   449  457  465  467  480  503  505  507  519  523  525  531  533  536
#   541  542  545  547  549  553  558  572  573  579  581  594  603  605
#   609  622  624  630  638  644  649  661  665  666  672  673  676  677
#   688  691  695  701  716  718  733  736  737  746  762  770  771  777
#   778  788  793  796  799  806  807  812  817  824  826  849  852  858
#   859  862  869  881  898  900  903  914  921  923  932  936  938  941
#   946  948  949  952  965  968  974  976  979  983  984  985  986  989
#   994  999 1001 1005 1009 1023 1034 1035 1040 1041 1047 1053 1061 1067
#  1073 1080 1083 1088 1091 1106 1107 1108 1111 1118 1125 1131 1137 1149
#  1151 1156 1167 1168 1170 1172 1175 1177 1188 1192 1196 1201 1204 1206
#  1222 1225 1226 1228 1229 1233 1236 1246 1247 1261 1263 1265 1271 1272
#  1292 1293 1298 1299 1307 1312 1315 1317 1318 1322 1323 1326 1328 1329
#  1334 1340 1346 1358 1361 1375 1377 1378 1394 1398 1403 1412 1419 1422
#  1424 1426 1428 1432 1441 1443 1448 1465 1469 1480 1490 1496 1502 1503
#  1509 1521 1523 1525 1526 1533 1534 1546 1573 1574 1580 1583 1596 1597
#  1598 1618 1621 1622 1627 1635 1644]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-large-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2393: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Done setting up optimizer
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch:   0%|          | 0/7 [00:00<?, ?it/s]
# In epoch  0
#
# Epoch loss is 0.7126099921406808
# Epoch accuracy is 0.6575757575757576
# In epoch  1
#
# Epoch loss is 0.8995337411945005
# Epoch accuracy is 0.7757575757575758
# In epoch  2
#
# Epoch loss is 0.8501734450886631
# Epoch accuracy is 0.7515151515151515
# In epoch  3
#
# Epoch loss is 0.6866117703844263
# Epoch accuracy is 0.7575757575757576
# In epoch  4
#
# Epoch loss is 0.5124353640148387
# Epoch accuracy is 0.7848484848484848
# In epoch  5
#
# Epoch loss is 0.3833982929343051
# Epoch accuracy is 0.8151515151515152
# In epoch  6
#
# Epoch loss is 0.3324679399351521
# Epoch accuracy is 0.8363636363636363
# The expanded size of the tensor (534) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 534].  Tensor sizes: [1, 512]
# The expanded size of the tensor (706) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 706].  Tensor sizes: [1, 512]
# The expanded size of the tensor (649) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 649].  Tensor sizes: [1, 512]
# The expanded size of the tensor (717) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 717].  Tensor sizes: [1, 512]
# The expanded size of the tensor (559) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 559].  Tensor sizes: [1, 512]
# The expanded size of the tensor (608) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 608].  Tensor sizes: [1, 512]
# The expanded size of the tensor (609) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 609].  Tensor sizes: [1, 512]
# The expanded size of the tensor (610) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 610].  Tensor sizes: [1, 512]
# The expanded size of the tensor (567) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 567].  Tensor sizes: [1, 512]
# The expanded size of the tensor (751) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 751].  Tensor sizes: [1, 512]
# The expanded size of the tensor (565) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 565].  Tensor sizes: [1, 512]
# The expanded size of the tensor (534) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 534].  Tensor sizes: [1, 512]
# The expanded size of the tensor (635) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 635].  Tensor sizes: [1, 512]
# The expanded size of the tensor (624) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 624].  Tensor sizes: [1, 512]
# The expanded size of the tensor (767) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 767].  Tensor sizes: [1, 512]
# The expanded size of the tensor (572) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 572].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2294) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2294].  Tensor sizes: [1, 512]
# The expanded size of the tensor (635) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 635].  Tensor sizes: [1, 512]
# The expanded size of the tensor (581) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 581].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2452) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2452].  Tensor sizes: [1, 512]
# The expanded size of the tensor (547) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 547].  Tensor sizes: [1, 512]
# The expanded size of the tensor (551) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 551].  Tensor sizes: [1, 512]
# The expanded size of the tensor (555) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 555].  Tensor sizes: [1, 512]
# The expanded size of the tensor (626) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 626].  Tensor sizes: [1, 512]
# The expanded size of the tensor (530) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 530].  Tensor sizes: [1, 512]
# The expanded size of the tensor (628) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 628].  Tensor sizes: [1, 512]
# The expanded size of the tensor (680) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 680].  Tensor sizes: [1, 512]
# The expanded size of the tensor (684) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 684].  Tensor sizes: [1, 512]
# The expanded size of the tensor (681) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 681].  Tensor sizes: [1, 512]
# The expanded size of the tensor (681) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 681].  Tensor sizes: [1, 512]
# The expanded size of the tensor (555) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 555].  Tensor sizes: [1, 512]
# The expanded size of the tensor (541) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 541].  Tensor sizes: [1, 512]
# The expanded size of the tensor (537) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 537].  Tensor sizes: [1, 512]
# The expanded size of the tensor (680) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 680].  Tensor sizes: [1, 512]
# The expanded size of the tensor (573) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 573].  Tensor sizes: [1, 512]
# The expanded size of the tensor (578) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 578].  Tensor sizes: [1, 512]
# The expanded size of the tensor (654) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 654].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2297) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2297].  Tensor sizes: [1, 512]
# The expanded size of the tensor (589) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 589].  Tensor sizes: [1, 512]
# The expanded size of the tensor (604) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 604].  Tensor sizes: [1, 512]
# The expanded size of the tensor (770) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 770].  Tensor sizes: [1, 512]
# The expanded size of the tensor (529) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 529].  Tensor sizes: [1, 512]
# The expanded size of the tensor (594) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 594].  Tensor sizes: [1, 512]
# The expanded size of the tensor (594) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 594].  Tensor sizes: [1, 512]
# The expanded size of the tensor (520) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 520].  Tensor sizes: [1, 512]
# The expanded size of the tensor (814) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 814].  Tensor sizes: [1, 512]
# The expanded size of the tensor (766) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 766].  Tensor sizes: [1, 512]
# The expanded size of the tensor (594) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 594].  Tensor sizes: [1, 512]
# The expanded size of the tensor (523) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 523].  Tensor sizes: [1, 512]
# The expanded size of the tensor (554) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 554].  Tensor sizes: [1, 512]
# The expanded size of the tensor (682) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 682].  Tensor sizes: [1, 512]
# The expanded size of the tensor (514) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 514].  Tensor sizes: [1, 512]
# The expanded size of the tensor (557) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 557].  Tensor sizes: [1, 512]
# The expanded size of the tensor (553) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 553].  Tensor sizes: [1, 512]
# The expanded size of the tensor (588) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 588].  Tensor sizes: [1, 512]
# The expanded size of the tensor (539) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 539].  Tensor sizes: [1, 512]
# The expanded size of the tensor (695) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 695].  Tensor sizes: [1, 512]
# The expanded size of the tensor (674) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 674].  Tensor sizes: [1, 512]
# The expanded size of the tensor (666) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 666].  Tensor sizes: [1, 512]
# The expanded size of the tensor (581) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 581].  Tensor sizes: [1, 512]
# The expanded size of the tensor (623) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 623].  Tensor sizes: [1, 512]
# The expanded size of the tensor (609) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 609].  Tensor sizes: [1, 512]
# The expanded size of the tensor (577) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 577].  Tensor sizes: [1, 512]
# The expanded size of the tensor (530) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 530].  Tensor sizes: [1, 512]
# The expanded size of the tensor (630) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 630].  Tensor sizes: [1, 512]
# The expanded size of the tensor (546) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 546].  Tensor sizes: [1, 512]
# The expanded size of the tensor (592) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 592].  Tensor sizes: [1, 512]
# The expanded size of the tensor (804) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 804].  Tensor sizes: [1, 512]
# The expanded size of the tensor (770) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 770].  Tensor sizes: [1, 512]
# The expanded size of the tensor (552) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 552].  Tensor sizes: [1, 512]
# The expanded size of the tensor (622) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 622].  Tensor sizes: [1, 512]
# The expanded size of the tensor (514) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 514].  Tensor sizes: [1, 512]
# The expanded size of the tensor (649) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 649].  Tensor sizes: [1, 512]
# The expanded size of the tensor (609) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 609].  Tensor sizes: [1, 512]
# ...
#   472  474  484  488  492  502  508  509  510  520  524  540  550  556
#   562  563  564  565  577  586  592  600  608  612  623  627  632  639
#   640  641  642  645  646  647  648  659  663  681  683  686  687  698
#   699  702  709  719  725  729  742  747  748  749  751  763  766  769
#   775  776  779  791  794  795  797  800  804  805  815  821  831  835
#   840  854  856  860  863  870  871  877  878  880  883  891  896  897
#   913  928  929  951  954  955  956  957  960  972  975  981  995 1012
#  1014 1016 1017 1020 1021 1025 1028 1038 1044 1045 1051 1056 1059 1060
#  1064 1071 1076 1082 1086 1095 1104 1109 1122 1123 1126 1129 1130 1135
#  1136 1143 1147 1152 1153 1154 1158 1162 1171 1180 1183 1184 1186 1194
#  1207 1215 1218 1224 1238 1241 1248 1250 1254 1256 1257 1264 1266 1267
#  1275 1282 1291 1294 1297 1300 1306 1321 1327 1332 1337 1338 1349 1354
#  1363 1367 1369 1371 1372 1382 1386 1390 1395 1396 1397 1400 1405 1408
#  1409 1410 1411 1413 1427 1430 1434 1437 1438 1439 1444 1451 1452 1454
#  1457 1459 1460 1462 1472 1478 1482 1483 1484 1485 1486 1494 1495 1499
#  1500 1504 1505 1508 1510 1513 1515 1518 1522 1528 1540 1543 1545 1548
#  1550 1553 1558 1564 1568 1578 1581 1584 1590 1593 1594 1595 1599 1602
#  1603 1616 1619 1624 1629 1638 1642]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-large-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2393: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Done setting up optimizer
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch:   0%|          | 0/7 [00:00<?, ?it/s]
# In epoch  0
#
# Epoch loss is 0.7102546647123212
# Epoch accuracy is 0.5272727272727272
# In epoch  1
#
# Epoch loss is 0.7268085034453905
# Epoch accuracy is 0.5272727272727272
# In epoch  2
#
# Epoch loss is 0.7848743001940308
# Epoch accuracy is 0.7363636363636363
# In epoch  3
#
# Epoch loss is 0.8477795186660313
# Epoch accuracy is 0.7575757575757576
# In epoch  4
#
# Epoch loss is 0.7186589330611101
# Epoch accuracy is 0.7848484848484848
# In epoch  5
#
# Epoch loss is 0.6184089294999904
# Epoch accuracy is 0.7757575757575758
# In epoch  6
#
# Epoch loss is 0.5537527037925295
# Epoch accuracy is 0.793939393939394
# The expanded size of the tensor (515) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 515].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1243) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1243].  Tensor sizes: [1, 512]
# The expanded size of the tensor (530) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 530].  Tensor sizes: [1, 512]
# The expanded size of the tensor (921) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 921].  Tensor sizes: [1, 512]
# The expanded size of the tensor (605) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 605].  Tensor sizes: [1, 512]
# The expanded size of the tensor (713) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 713].  Tensor sizes: [1, 512]
# The expanded size of the tensor (619) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 619].  Tensor sizes: [1, 512]
# The expanded size of the tensor (514) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 514].  Tensor sizes: [1, 512]
# The expanded size of the tensor (543) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 543].  Tensor sizes: [1, 512]
# The expanded size of the tensor (523) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 523].  Tensor sizes: [1, 512]
# The expanded size of the tensor (689) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 689].  Tensor sizes: [1, 512]
# The expanded size of the tensor (576) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 576].  Tensor sizes: [1, 512]
# The expanded size of the tensor (595) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 595].  Tensor sizes: [1, 512]
# The expanded size of the tensor (536) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 536].  Tensor sizes: [1, 512]
# The expanded size of the tensor (615) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 615].  Tensor sizes: [1, 512]
# The expanded size of the tensor (604) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 604].  Tensor sizes: [1, 512]
# The expanded size of the tensor (658) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 658].  Tensor sizes: [1, 512]
# The expanded size of the tensor (633) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 633].  Tensor sizes: [1, 512]
# The expanded size of the tensor (750) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 750].  Tensor sizes: [1, 512]
# The expanded size of the tensor (770) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 770].  Tensor sizes: [1, 512]
# The expanded size of the tensor (571) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 571].  Tensor sizes: [1, 512]
# The expanded size of the tensor (615) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 615].  Tensor sizes: [1, 512]
# The expanded size of the tensor (679) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 679].  Tensor sizes: [1, 512]
# The expanded size of the tensor (614) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 614].  Tensor sizes: [1, 512]
# The expanded size of the tensor (555) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 555].  Tensor sizes: [1, 512]
# The expanded size of the tensor (770) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 770].  Tensor sizes: [1, 512]
# The expanded size of the tensor (541) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 541].  Tensor sizes: [1, 512]
# The expanded size of the tensor (564) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 564].  Tensor sizes: [1, 512]
# The expanded size of the tensor (514) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 514].  Tensor sizes: [1, 512]
# The expanded size of the tensor (921) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 921].  Tensor sizes: [1, 512]
# The expanded size of the tensor (582) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 582].  Tensor sizes: [1, 512]
# The expanded size of the tensor (561) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 561].  Tensor sizes: [1, 512]
# The expanded size of the tensor (529) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 529].  Tensor sizes: [1, 512]
# The expanded size of the tensor (677) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 677].  Tensor sizes: [1, 512]
# The expanded size of the tensor (514) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 514].  Tensor sizes: [1, 512]
# The expanded size of the tensor (552) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 552].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2294) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2294].  Tensor sizes: [1, 512]
# The expanded size of the tensor (566) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 566].  Tensor sizes: [1, 512]
# The expanded size of the tensor (713) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 713].  Tensor sizes: [1, 512]
# The expanded size of the tensor (612) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 612].  Tensor sizes: [1, 512]
# The expanded size of the tensor (555) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 555].  Tensor sizes: [1, 512]
# The expanded size of the tensor (579) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 579].  Tensor sizes: [1, 512]
# The expanded size of the tensor (735) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 735].  Tensor sizes: [1, 512]
# The expanded size of the tensor (566) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 566].  Tensor sizes: [1, 512]
# The expanded size of the tensor (533) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 533].  Tensor sizes: [1, 512]
# The expanded size of the tensor (592) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 592].  Tensor sizes: [1, 512]
# The expanded size of the tensor (1284) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 1284].  Tensor sizes: [1, 512]
# The expanded size of the tensor (528) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 528].  Tensor sizes: [1, 512]
# The expanded size of the tensor (538) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 538].  Tensor sizes: [1, 512]
# The expanded size of the tensor (921) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 921].  Tensor sizes: [1, 512]
# The expanded size of the tensor (533) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 533].  Tensor sizes: [1, 512]
# The expanded size of the tensor (678) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 678].  Tensor sizes: [1, 512]
# The expanded size of the tensor (564) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 564].  Tensor sizes: [1, 512]
# The expanded size of the tensor (656) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 656].  Tensor sizes: [1, 512]
# The expanded size of the tensor (921) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 921].  Tensor sizes: [1, 512]
# The expanded size of the tensor (770) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 770].  Tensor sizes: [1, 512]
# The expanded size of the tensor (908) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 908].  Tensor sizes: [1, 512]
# The expanded size of the tensor (551) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 551].  Tensor sizes: [1, 512]
# The expanded size of the tensor (558) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 558].  Tensor sizes: [1, 512]
# The expanded size of the tensor (2852) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 2852].  Tensor sizes: [1, 512]
# The expanded size of the tensor (606) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 606].  Tensor sizes: [1, 512]
# The expanded size of the tensor (532) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 532].  Tensor sizes: [1, 512]
# The expanded size of the tensor (521) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 521].  Tensor sizes: [1, 512]
# The expanded size of the tensor (580) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 580].  Tensor sizes: [1, 512]
# The expanded size of the tensor (555) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 555].  Tensor sizes: [1, 512]
# The expanded size of the tensor (529) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 529].  Tensor sizes: [1, 512]
# The expanded size of the tensor (555) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 555].  Tensor sizes: [1, 512]
# The expanded size of the tensor (612) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 612].  Tensor sizes: [1, 512]
# The expanded size of the tensor (770) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 770].  Tensor sizes: [1, 512]
# The expanded size of the tensor (921) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 921].  Tensor sizes: [1, 512]
# The expanded size of the tensor (538) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 538].  Tensor sizes: [1, 512]
# The expanded size of the tensor (581) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 581].  Tensor sizes: [1, 512]
# The expanded size of the tensor (516) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 516].  Tensor sizes: [1, 512]
# The expanded size of the tensor (555) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 555].  Tensor sizes: [1, 512]
# The expanded size of the tensor (626) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 626].  Tensor sizes: [1, 512]
# The expanded size of the tensor (580) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 580].  Tensor sizes: [1, 512]
# The expanded size of the tensor (579) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 579].  Tensor sizes: [1, 512]
# The expanded size of the tensor (766) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 766].  Tensor sizes: [1, 512]
# The expanded size of the tensor (677) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 677].  Tensor sizes: [1, 512]
# The expanded size of the tensor (527) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 527].  Tensor sizes: [1, 512]
# The expanded size of the tensor (703) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 703].  Tensor sizes: [1, 512]
# The expanded size of the tensor (588) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 588].  Tensor sizes: [1, 512]
# The expanded size of the tensor (687) must match the existing size (512) at non-singleton dimension 1.  Target sizes: [1, 687].  Tensor sizes: [1, 512]
#               precision    recall  f1-score   support
#
#        False       0.81      0.78      0.79       122
#         True       0.79      0.81      0.80       124
#
#     accuracy                           0.80       246
#    macro avg       0.80      0.80      0.80       246
# weighted avg       0.80      0.80      0.80       246

# %%
print("The mean accuracy score is", np.mean(CV_accuracy_array))
# Out:
# The mean accuracy score is 0.7588255251729537

# %%
print("The standard deviation for accuracy is", np.std(CV_accuracy_array))
# Out:
# The standard deviation for accuracy is 0.10543565049533261

# %%
print("The mean macro avg score is", np.mean(CV_macro_avg_array))
# Out:
# The mean macro avg score is 0.7191131451767939

# %%
print("The standard deviation for macro avg score is", np.std(CV_macro_avg_array))
# Out:
# The standard deviation for macro avg score is 0.18265632380146823

# %%
print("The mean weighted avg score is", np.mean(CV_weighted_avg_array))
# Out:
# The mean weighted avg score is 0.7272090426821908

# %%
print("The standard deviation for weighted avg score is", np.std(CV_weighted_avg_array))
# Out:
# The standard deviation for weighted avg score is 0.16923427469944516
